# %% [markdown]
# # RESEARCH PROJECT ON EMPLOYEE ATTRITION DATASET

# %%
#  importing libraries
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.preprocessing import LabelEncoder
encode = LabelEncoder()

# %%
# Importing the Dataset
data = pd.read_csv("/Users/ananya/Downloads/Employee-Attrition_Dataset.csv")

# %%
data.head(10)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
# 5   32        No  Travel_Frequently       1005  Research & Development
# 6   59        No      Travel_Rarely       1324  Research & Development
# 7   30        No      Travel_Rarely       1358  Research & Development
# 8   38        No  Travel_Frequently        216  Research & Development
# 9   36        No      Travel_Rarely       1299  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# ...

# %%
len(data)
# Out:
# 1470

# %% [markdown]
# ## DATA CLEANING

# %%
# check for null values
data.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
# check for outliers
for col in data.columns:
    if data[col].dtype !=object:
        x = data[col]
        sb.boxplot(x=x)
        plt.show()

# %%
#droping some of the unwanted columns
data=data.drop(['EmployeeCount','EmployeeNumber','StandardHours','Over18'], axis=1)

# %%
data = data.drop(['PerformanceRating'],axis=1)

# %% [markdown]
# ### REMOVING THE OUTLIERS

# %%
Q1=np.percentile(data.MonthlyIncome,25,interpolation='midpoint')
Q2=np.percentile(data.MonthlyIncome,50,interpolation='midpoint')
Q3=np.percentile(data.MonthlyIncome,75,interpolation='midpoint')

IQR=Q3-Q1
low_lim= Q1 - 1.5*IQR 
up_lim= Q3 + 1.5*IQR

data.MonthlyIncome = np.where(data.MonthlyIncome >Q3 , Q3,data.MonthlyIncome)

# %%
Q1=np.percentile(data.TotalWorkingYears,25,interpolation='midpoint')
Q2=np.percentile(data.TotalWorkingYears,50,interpolation='midpoint')
Q3=np.percentile(data.TotalWorkingYears,75,interpolation='midpoint')

IQR=Q3-Q1
low_lim= Q1 - 1.5*IQR 
up_lim= Q3 + 1.5*IQR

data.TotalWorkingYears = np.where(data.TotalWorkingYears >Q3 , Q3,data.TotalWorkingYears)

# %%
Q1=np.percentile(data.YearsAtCompany,25,interpolation='midpoint')
Q2=np.percentile(data.YearsAtCompany,50,interpolation='midpoint')
Q3=np.percentile(data.YearsAtCompany,75,interpolation='midpoint')

IQR=Q3-Q1
low_lim= Q1 - 1.5*IQR 
up_lim= Q3 + 1.5*IQR
col_med = data.YearsAtCompany.mean()

data.YearsAtCompany = np.where(data.YearsAtCompany >Q3 , Q3,data.YearsAtCompany)

# %%
Q1=np.percentile(data.YearsSinceLastPromotion,25,interpolation='midpoint')
Q2=np.percentile(data.YearsSinceLastPromotion,50,interpolation='midpoint')
Q3=np.percentile(data.YearsSinceLastPromotion,75,interpolation='midpoint')

IQR=Q3-Q1
low_lim= Q1 - 1.5*IQR 
up_lim= Q3 + 1.5*IQR
col_med = x.mean()

data.YearsSinceLastPromotion = np.where(data.YearsSinceLastPromotion >Q3 , Q3,data.YearsSinceLastPromotion)

# %%
Q1=np.percentile(data.YearsInCurrentRole,25,interpolation='midpoint')
Q2=np.percentile(data.YearsInCurrentRole,50,interpolation='midpoint')
Q3=np.percentile(data.YearsInCurrentRole,75,interpolation='midpoint')

IQR=Q3-Q1
low_lim= Q1 - 1.5*IQR 
up_lim= Q3 + 1.5*IQR
col_med = data.YearsInCurrentRole.mean()

data.YearsInCurrentRole = np.where(data.YearsInCurrentRole >Q3 , Q3,data.YearsInCurrentRole)

# %%
Q1=np.percentile(data.YearsWithCurrManager,25,interpolation='midpoint')
Q2=np.percentile(data.YearsWithCurrManager,50,interpolation='midpoint')
Q3=np.percentile(data.YearsWithCurrManager,75,interpolation='midpoint')

IQR=Q3-Q1
low_lim= Q1 - 1.5*IQR 
up_lim= Q3 + 1.5*IQR
col_med = data.YearsWithCurrManager.mean()

data.YearsWithCurrManager = np.where(data.YearsWithCurrManager>Q3 , Q3,data.YearsWithCurrManager)

# %%
# check if outliers have been removed 
for col in data.columns:
    if data[col].dtype !=object:
        x = data[col]
        sb.boxplot(x=x)
        plt.show()

# %% [markdown]
# ## DATA ANALYSIS AND PREPROCESSING

# %%
data['Attrition'].value_counts()
# Out:
# 0.0    1233
# 1.0     237
# Name: Attrition, dtype: int64

# %%
sb.countplot(data['Attrition'], label = 'count')
# Out:
# /Users/ananya/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %%
# Analysing different values in object data types
for column in data.columns:
    if data[column].dtype == object:
        print(str(column) + ' : ' + str(data[column].unique()))
        print(data[column].value_counts())
        print("_________________________________________________________________")

# %%
data.head(10)
# Out:
#         Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0  0.547619        1.0             1.0   0.715820         1.0
# 1  0.738095        0.0             0.5   0.126700         0.5
# 2  0.452381        1.0             1.0   0.909807         0.5
# 3  0.357143        0.0             0.5   0.923407         0.5
# 4  0.214286        0.0             1.0   0.350036         0.5
# 5  0.333333        0.0             0.5   0.646385         0.5
# 6  0.976190        0.0             1.0   0.874732         0.5
# 7  0.285714        0.0             1.0   0.899069         0.5
# 8  0.476190        0.0             0.5   0.081603         0.5
# 9  0.428571        0.0             1.0   0.856836         0.5
#
#    DistanceFromHome  Education  EducationField  EnvironmentSatisfaction  \
# 0          0.000000       0.25             0.2                 0.333333
# 1          0.250000       0.00             0.2                 0.666667
# ...

# %%
data.loc[:,'Attrition'] = encode.fit_transform(data.loc[:, 'Attrition'].values)
data.loc[:,'MaritalStatus'] = encode.fit_transform(data.loc[:, 'MaritalStatus'].values)
data.loc[:,'BusinessTravel'] = encode.fit_transform(data.loc[:, 'BusinessTravel'].values)
data.loc[:,'Department'] = encode.fit_transform(data.loc[:, 'Department'].values)
data.loc[:,'EducationField'] = encode.fit_transform(data.loc[:, 'EducationField'].values)
data.loc[:,'Gender'] = encode.fit_transform(data.loc[:, 'Gender'].values)
data.loc[:,'JobRole'] = encode.fit_transform(data.loc[:, 'JobRole'].values)
data.loc[:,'OverTime'] = encode.fit_transform(data.loc[:, 'OverTime'].values)

# %%
#normalization of data 
for col in data.columns:
    data[col] = (data[col]-data[col].min())/(data[col].max()-data[col].min())

# %%
data.head()
# Out:
#         Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0  0.547619        1.0             1.0   0.715820         1.0
# 1  0.738095        0.0             0.5   0.126700         0.5
# 2  0.452381        1.0             1.0   0.909807         0.5
# 3  0.357143        0.0             0.5   0.923407         0.5
# 4  0.214286        0.0             1.0   0.350036         0.5
#
#    DistanceFromHome  Education  EducationField  EnvironmentSatisfaction  \
# 0          0.000000       0.25             0.2                 0.333333
# 1          0.250000       0.00             0.2                 0.666667
# 2          0.035714       0.25             0.8                 1.000000
# 3          0.071429       0.75             0.2                 1.000000
# 4          0.035714       0.00             0.6                 0.000000
#
#    Gender  ...  PercentSalaryHike  RelationshipSatisfaction  StockOptionLevel  \
# ...

# %% [markdown]
# ### studying correlation between features of the dataset using correlation heatmap

# %%
#
plt.figure(figsize = (40,30))
sb.heatmap(data.corr(),annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## PREDICTION USING ML MODELS

# %% [markdown]
# ### For this dataset we will use models - LogisticRegression, Deciidon Tree, Random Forest and Naive Bayes,KNN and XGBoost

# %% [markdown]
# STEP1 : Split The dataset into independent and dependent variables and train and test variables

# %%
x = data
x = x.drop("Attrition",axis=1)
y = data.Attrition

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, Y_train, Y_test = train_test_split(x,y, test_size = 0.25, random_state = 10)

# %%
from sklearn.metrics import accuracy_score

#  LOGISTIC REGRESSION
from sklearn.linear_model import LogisticRegression
log = LogisticRegression(penalty = 'none',random_state = 15)
log.fit(x_train, Y_train)


#  DECISION TREE
from sklearn.tree import DecisionTreeClassifier
tree = DecisionTreeClassifier(random_state = 40, criterion= 'gini', max_depth=11)
tree.fit(x_train, Y_train)


#  RANDOM FOREST 
from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier(n_estimators=10,criterion= 'gini')
forest.fit(x_train, Y_train)


#  NAIVE BAYES
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(x_train, Y_train)

# KNN CLASSIFIER
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=4)
knn.fit(x_train, Y_train)

# Import Gradient Boost Classifier for modeling
from sklearn.ensemble import GradientBoostingClassifier
gbm = GradientBoostingClassifier()

# Fitting the model
gbm.fit(x_train, Y_train)

print('Logistic regression: ', log.score(x_train, Y_train))
print('Accuracy', accuracy_score(Y_test, log.predict(x_test)))

print('Decision tree: ', tree.score(x_train, Y_train))
#print('Accuracy', accuracy_score(Y_test, tree.predict(x_test)))

print('Random forest: ', forest.score(x_train, Y_train))
#print('Accuracy', accuracy_score(Y_test, forest.predict(x_test)))

print('Naive Bayes: ', gnb.score(x_train, Y_train))
#print('Accuracy', accuracy_score(Y_test, gnb.predict(x_test)))

print('KNN Classifier: ', knn.score(x_train, Y_train))
#print('Accuracy', accuracy_score(Y_test, knn.predict(x_test)))

print('GBM Classifier: ', gbm.score(x_train, Y_train))
print('Accuracy', accuracy_score(Y_test, gbm.predict(x_test)))
# Out:
# Logistic regression:  0.8802177858439202
# Accuracy 0.8641304347826086
# Decision tree:  0.9945553539019963
# Random forest:  0.984573502722323
# Naive Bayes:  0.8239564428312159
# KNN Classifier:  0.8702359346642469
# GBM Classifier:  0.957350272232305
# Accuracy 0.875

# %% [markdown]
# Here we can see that naive bayes model has the highest accuracy

# %% [markdown]
# ### Plotting the Confusion Matrix for All the Models

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

# Logistic Regression Model
conf_matrix = confusion_matrix(y_true=Y_test, y_pred=log.predict(x_test))
 
fig, ax = plt.subplots(figsize=(10, 10))
ax.matshow(conf_matrix, cmap=plt.cm.Oranges, alpha=0.3)
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(x=j, y=i,s=conf_matrix[i, j], va='center', ha='center', size='xx-large')
 
plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix', fontsize=18)
plt.show()  

print('Precision: %.3f' % precision_score(Y_test, log.predict(x_test)))
print('Recall: %.3f' % recall_score(Y_test, log.predict(x_test)))
print('Accuracy: %.3f' % accuracy_score(Y_test, log.predict(x_test)))
print('F1 Score: %.3f' % f1_score(Y_test, log.predict(x_test)))
# Out:
# Precision: 0.800
# Recall: 0.353
# Accuracy: 0.864
# F1 Score: 0.490

# %%
# Decision Tree Model
conf_matrix = confusion_matrix(y_true=Y_test, y_pred=tree.predict(x_test))
 
fig, ax = plt.subplots(figsize=(10, 10))
ax.matshow(conf_matrix, cmap=plt.cm.Oranges, alpha=0.3)
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(x=j, y=i,s=conf_matrix[i, j], va='center', ha='center', size='xx-large')
 
plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix', fontsize=18)
plt.show()  

print('Precision: %.3f' % precision_score(Y_test, tree.predict(x_test)))
print('Recall: %.3f' % recall_score(Y_test, tree.predict(x_test)))
print('Accuracy: %.3f' % accuracy_score(Y_test, tree.predict(x_test)))
print('F1 Score: %.3f' % f1_score(Y_test, tree.predict(x_test)))
# Out:
# Precision: 0.526
# Recall: 0.441
# Accuracy: 0.823
# F1 Score: 0.480

# %%
# Random Forest Model
conf_matrix = confusion_matrix(y_true=Y_test, y_pred=forest.predict(x_test))
 
fig, ax = plt.subplots(figsize=(10, 10))
ax.matshow(conf_matrix, cmap=plt.cm.Oranges, alpha=0.3)
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(x=j, y=i,s=conf_matrix[i, j], va='center', ha='center', size='xx-large')
 
plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix', fontsize=18)
plt.show()  

print('Precision: %.3f' % precision_score(Y_test, forest.predict(x_test)))
print('Recall: %.3f' % recall_score(Y_test, forest.predict(x_test)))
print('Accuracy: %.3f' % accuracy_score(Y_test, forest.predict(x_test)))
print('F1 Score: %.3f' % f1_score(Y_test, forest.predict(x_test)))
# Out:
# Precision: 0.786
# Recall: 0.162
# Accuracy: 0.837
# F1 Score: 0.268

# %%
# Naive Bayes Model
conf_matrix = confusion_matrix(y_true=Y_test, y_pred=gnb.predict(x_test))
 
fig, ax = plt.subplots(figsize=(10, 10))
ax.matshow(conf_matrix, cmap=plt.cm.Oranges, alpha=0.3)
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(x=j, y=i,s=conf_matrix[i, j], va='center', ha='center', size='xx-large')
 
plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix', fontsize=18)
plt.show()  

print('Precision: %.3f' % precision_score(Y_test, gnb.predict(x_test)))
print('Recall: %.3f' % recall_score(Y_test, gnb.predict(x_test)))
print('Accuracy: %.3f' % accuracy_score(Y_test, gnb.predict(x_test)))
print('F1 Score: %.3f' % f1_score(Y_test, gnb.predict(x_test)))
# Out:
# Precision: 0.629
# Recall: 0.574
# Accuracy: 0.859
# F1 Score: 0.600

# %%
# KNN
conf_matrix = confusion_matrix(y_true=Y_test, y_pred=knn.predict(x_test))
 
fig, ax = plt.subplots(figsize=(10, 10))
ax.matshow(conf_matrix, cmap=plt.cm.Oranges, alpha=0.3)
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(x=j, y=i,s=conf_matrix[i, j], va='center', ha='center', size='xx-large')
 
plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix', fontsize=18)
plt.show()  

print('Precision: %.3f' % precision_score(Y_test, knn.predict(x_test)))
print('Recall: %.3f' % recall_score(Y_test, knn.predict(x_test)))
print('Accuracy: %.3f' % accuracy_score(Y_test, knn.predict(x_test)))
print('F1 Score: %.3f' % f1_score(Y_test, knn.predict(x_test)))
# Out:
# Precision: 0.667
# Recall: 0.088
# Accuracy: 0.823
# F1 Score: 0.156

# %%
# Random Forest Model
conf_matrix = confusion_matrix(y_true=Y_test, y_pred=regressor.predict(x_test))
 
fig, ax = plt.subplots(figsize=(10, 10))
ax.matshow(conf_matrix, cmap=plt.cm.Oranges, alpha=0.3)
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(x=j, y=i,s=conf_matrix[i, j], va='center', ha='center', size='xx-large')
 
plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix', fontsize=18)
plt.show()  

print('Precision: %.3f' % precision_score(Y_test, regressor.predict(x_test)))
print('Recall: %.3f' % recall_score(Y_test, regressor.predict(x_test)))
print('Accuracy: %.3f' % accuracy_score(Y_test, regressor.predict(x_test)))
print('F1 Score: %.3f' % f1_score(Y_test, regressor.predict(x_test)))
# Out:
# Precision: 0.742
# Recall: 0.338
# Accuracy: 0.856
# F1 Score: 0.465

# %%
# Gradient Boost
conf_matrix = confusion_matrix(y_true=Y_test, y_pred= gbm.predict(x_test))
 
fig, ax = plt.subplots(figsize=(10, 10))
ax.matshow(conf_matrix, cmap=plt.cm.Oranges, alpha=0.3)
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(x=j, y=i,s=conf_matrix[i, j], va='center', ha='center', size='xx-large')
 
plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix', fontsize=18)
plt.show()  

print('Precision: %.3f' % precision_score(Y_test, gbm.predict(x_test)))
print('Recall: %.3f' % recall_score(Y_test, gbm.predict(x_test)))
print('Accuracy: %.3f' % accuracy_score(Y_test, gbm.predict(x_test)))
print('F1 Score: %.3f' % f1_score(Y_test, gbm.predict(x_test)))
# Out:
# Precision: 0.844
# Recall: 0.397
# Accuracy: 0.875
# F1 Score: 0.540

# %% [markdown]
# ### PLOTTING A GRAPH FOR THE ACCURACY SCORES

# %%
plt.figure(figsize = (15,7))
Accuracy_Test_data= [0.864,0.823,0.837,0.859,0.823,0.856,0.875]
plt.plot(Accuracy_Test_data, label ='Accuracy Scores')
plt.title('Accuracy Score Of Models')
plt.legend()
plt.show()

# %% [markdown]
# ### PLOTTING A GRAPH FOR THE PRECISION SCORES

# %%
plt.figure(figsize = (15,7))
precision_Test_data= [0.800,0.526, 0.786, 0.629,0.667,0.742,0.844]
plt.plot(precision_Test_data, label ='Precision Scores')
plt.title('Precision Score Of Models')
plt.legend()
plt.show()

# %% [markdown]
# ### PLOTTING GRAPH FOR RECALL

# %%
plt.figure(figsize = (15,7))
recall_Test_data= [0.353,0.441,0.162,0.574,0.088,0.338,0.397]
plt.plot(recall_Test_data, label ='Recall')
plt.title('Recall')
plt.legend()
plt.show()

# %% [markdown]
# ###  F1-SCORE

# %%
plt.figure(figsize = (15,7))
f1_Test_data= [0.490,0.480,0.268,0.600,0.156,0.465,0.540]
plt.plot(f1_Test_data, label ='Recall')
plt.title('Recall')
plt.legend()
plt.show()
